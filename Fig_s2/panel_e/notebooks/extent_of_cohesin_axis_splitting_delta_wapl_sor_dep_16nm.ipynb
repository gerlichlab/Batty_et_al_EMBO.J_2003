# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import numpy as np
from scipy import ndimage as ndi
import skimage
from skimage import io, filters, morphology
import pandas as pd
import glob
import random
import glob
import seaborn as sns
from scipy import stats
from scipy.signal import chirp, find_peaks, peak_widths
import pandas as pd
from pathlib import Path
import scipy.stats
import os
from scipy import ndimage
import math
from operator import itemgetter
from matplotlib import pyplot
#from read_roi import read_roi_zip
import matplotlib.ticker as ticker
import plotly.express as px

# %%
path_axis = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_sor_dep_16nm/whole_axis_length/"

csv_files = glob.glob(path_axis + "*.csv")

### Fetch all files in path

# %%
#csv_files

# %%
#read in length of whole cohesin axis for wapl depleted cells
all_df = []

#read in csv files
for file in csv_files:
    df = pd.read_csv(file, index_col=0, header=0)
    all_df.append(df)
    #change column names
    df.columns = ['image_name', 'area', 'mean', 'stddev', 'intden', 'rawintden', 'length']
    df.rename(columns = {'label':'image_name'}, inplace = True)
    df.rename(columns = {'length':'length_cohesin_axis'}, inplace = True)
    df["condition"] = "length_cohesin_axis"

#concat all dataframes together
frame = pd.concat(all_df, axis=0, ignore_index=True)
#remove duplicated rows
cols = frame.columns

#slice relevant columns into final dataframe
length_cohesin_axis = frame[['image_name','length_cohesin_axis']]

#fully_prometa_chromatin_fragment_length = fully_prometa_chromatin_fragment_length.sort_values('chromatin_segment_length', ascending=False)
#fully_prometa_chromatin_fragment_length_reset = fully_prometa_chromatin_fragment_length.reset_index(drop=True)

results_dir = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/concat_csvs/"

length_cohesin_axis.to_csv(os.path.join(results_dir + "measure_length_cohesin_axis_wapl_sor_dep_16nm.csv"), index = False)
#average_length_wapl.to_csv(os.path.join(results_dir + "average_stats_resolved_dna_around_vermicelli_wapl_dep.csv"), index = False)

# %%
#read in length of single cohesin axes

# %%
length_cohesin_axis
# Out:
#                                             image_name  length_cohesin_axis
# 0    230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                4.656
# 1    230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                4.722
# 2    230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                4.017
# 3    230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                1.412
# 4    230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                2.504
# ..                                                 ...                  ...
# 228  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                1.728
# 229  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                1.269
# 230  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                1.904
# 231  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                1.656
# 232  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...                3.490
#
# [233 rows x 2 columns]

# %%
path_split = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_sor_dep_16nm/split_axis_length/"


csv_files = glob.glob(path_split + "*.csv")

### Fetch all files in path

# %%
#csv_files

# %%
all_df = []

#read in csv files
for file in csv_files:
    df = pd.read_csv(file, index_col=0, header=0)
    all_df.append(df)
    #change column names
    df.columns = ['image_name', 'area', 'mean', 'stddev', 'intden', 'rawintden', 'length']
    df.rename(columns = {'length':'length_split_cohesin_axis'}, inplace = True)
    df.rename(columns = {'label':'image_name'}, inplace = True)
    df["condition"] = "split_cohesin_axis_wapl_sor_depleted"

#concat all dataframes together
frame = pd.concat(all_df, axis=0, ignore_index=True)
#remove duplicated rows
cols = frame.columns
#dedup = frame[cols].loc[(frame[cols].shift() != frame[cols]).any(axis=1)]

#slice relevant columns into final dataframe
length_split_axis = frame[['image_name','length_split_cohesin_axis', 'condition']]

#fully_prometa_two_sister_segment = fully_prometa_two_sister_segment.sort_values('edu_segment_length', ascending=False)
#fully_prometa_two_sister_segment_reset = fully_prometa_two_sister_segment.reset_index(drop=True)

results_dir = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/concat_csvs/"

length_split_axis.to_csv(os.path.join(results_dir + "measure_length_split_axis_segments_wapl_sor_dep_16nm.csv"), index = False)
#average_length_wapl.to_csv(os.path.join(results_dir + "average_stats_resolved_dna_around_vermicelli_wapl_dep.csv"), index = False)

# %%
sum_cohesin_axis =  length_cohesin_axis.groupby(['image_name'], as_index=False)[['length_cohesin_axis']].sum()
sum_cohesin_axis
# Out:
#                                           image_name  length_cohesin_axis
# 0  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...               82.282
# 1  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...               77.446
# 2  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...               82.252
# 3  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...               70.192
# 4  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...               41.141
# 5  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...               57.603
# 6  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...               61.472
# 7  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...               53.344
# 8  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...               52.524
# 9  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...               65.779

# %%
sum_split_axis =  length_split_axis.groupby(['image_name'], as_index=False)[['length_split_cohesin_axis']].sum()
sum_split_axis
# Out:
#                                           image_name  \
# 0  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 1  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 2  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 3  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 4  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 5  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 6  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 7  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 8  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 9  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
#
#    length_split_cohesin_axis
# 0                     73.039
# 1                     69.518
# 2                     65.608
# 3                     57.887
# 4                     34.832
# 5                     52.177
# 6                     52.070
# 7                     43.824
# 8                     45.657
# 9                     55.667

# %%
frames_merged = sum_split_axis.merge(sum_cohesin_axis, on='image_name',  how = "right")
fraction_split_axis = (frames_merged.loc[:, "length_split_cohesin_axis"]) / (frames_merged.loc[:, "length_cohesin_axis"])
percentage_split_axis = ((frames_merged.loc[:, "length_split_cohesin_axis"]) / (frames_merged.loc[:, "length_cohesin_axis"]))*100

frames_merged["fraction_split_axis"] = fraction_split_axis
frames_merged["percentage_split_axis"] = percentage_split_axis

# %%
frames_merged
# Out:
#                                           image_name  \
# 0  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 1  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 2  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 3  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 4  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 5  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 6  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 7  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 8  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 9  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
#
#    length_split_cohesin_axis  length_cohesin_axis  fraction_split_axis  \
# 0                     73.039               82.282             0.887667
# 1                     69.518               77.446             0.897632
# 2                     65.608               82.252             0.797646
# 3                     57.887               70.192             0.824695
# 4                     34.832               41.141             0.846649
# 5                     52.177               57.603             0.905804
# 6                     52.070               61.472             0.847052
# 7                     43.824               53.344             0.821536
# 8                     45.657               52.524             0.869260
# 9                     55.667               65.779             0.846273
#
#    percentage_split_axis
# 0              88.766680
# 1              89.763190
# 2              79.764626
# 3              82.469512
# 4              84.664933
# 5              90.580352
# 6              84.705232
# 7              82.153569
# 8              86.925977
# 9              84.627313

# %%
fraction_single_axis = 1 - (frames_merged.loc[:, "fraction_split_axis"])

# %%
percentage_single_axis = fraction_single_axis *100

# %%
frames_merged["fraction_single_axes"] = fraction_single_axis
frames_merged["percentage_single_axes"] = percentage_single_axis

# %%
frames_merged
# Out:
#                                           image_name  \
# 0  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 1  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 2  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 3  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 4  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...
# 5  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 6  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 7  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 8  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
# 9  230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...
#
#    length_split_cohesin_axis  length_cohesin_axis  fraction_split_axis  \
# 0                     73.039               82.282             0.887667
# 1                     69.518               77.446             0.897632
# 2                     65.608               82.252             0.797646
# 3                     57.887               70.192             0.824695
# 4                     34.832               41.141             0.846649
# 5                     52.177               57.603             0.905804
# 6                     52.070               61.472             0.847052
# 7                     43.824               53.344             0.821536
# 8                     45.657               52.524             0.869260
# 9                     55.667               65.779             0.846273
#
#    percentage_split_axis  fraction_single_axes  percentage_single_axes
# 0              88.766680              0.112333               11.233320
# 1              89.763190              0.102368               10.236810
# 2              79.764626              0.202354               20.235374
# 3              82.469512              0.175305               17.530488
# 4              84.664933              0.153351               15.335067
# 5              90.580352              0.094196                9.419648
# 6              84.705232              0.152948               15.294768
# 7              82.153569              0.178464               17.846431
# 8              86.925977              0.130740               13.074023
# 9              84.627313              0.153727               15.372687

# %%
results_dir = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/final_output/"

# %%
frames_merged.to_csv(os.path.join(results_dir + "wapl_sororin_depleted_16nm_control_percentage_split_axes.csv"), index = False)
#average_length_wapl.to_csv(os.path.join(results_dir + "average_stats_resolved_dna_around_vermicelli_wapl_dep.csv"), index = False)

# %%
sor_fluor = pd.read_csv("/groups/gerlich/experiments/Experiments_005700/005765/quantify_mean_fluorescence_single_cells/1802_wapl_dep_sor_si_16nm_5675.csv")


#slice relevant columns into final dataframe
sor_fluor = sor_fluor[['image_name','mean_sororin']]

# %%
sor_fluor
# Out:
#                                            image_name  mean_sororin
# 0   230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...     90.538193
# 1   230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...    148.263986
# 2   230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...    109.423288
# 3   230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...    109.096639
# 4   230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...     82.471617
# 5   230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...    120.301472
# 6   230304_1802_wapl_dep_sor_si_16nm_rep1_zoom4_8_...    123.009347
# 7   230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...    139.876144
# 8   230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...     45.337791
# 9   230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...     62.109639
# 10  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...     96.064040
# 11  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...    128.112348
# 12  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...    111.535417
# 13  230304_1802_sor_si_16nm_rep2_zoom4_8_dna_scc1_...    127.090020

# %%
concat_frame = frames_merged = frames_merged.merge(sor_fluor, on='image_name',  how = "right")

# %%
concat_frame = concat_frame.dropna()
concat_frame = concat_frame[['image_name', 'percentage_split_axis', 'mean_sororin']]

# %%
concat_frame.to_csv(os.path.join(results_dir + "wapl_sororin_depleted_16nm_split_axes_mean_sor_fluorescence.csv"), index = False)
#average_length_wapl.to_csv(os.path.join(results_dir + "average_stats_resolved_dna_around_vermicelli_wapl_dep.csv"), index = False)
