# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import numpy as np
from scipy import ndimage as ndi
import skimage
from skimage import io, filters, morphology
import pandas as pd
import glob
import random
import glob
import seaborn as sns
from scipy import stats
from scipy.signal import chirp, find_peaks, peak_widths
import pandas as pd
from pathlib import Path
import scipy.stats
import os
from scipy import ndimage
import math
from operator import itemgetter
from matplotlib import pyplot
#from read_roi import read_roi_zip
import matplotlib.ticker as ticker
import plotly.express as px

# %%
path_axis = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/"


csv_files = glob.glob(path_axis + "*.csv")

### Fetch all files in path

# %%
csv_files
# Out:
# ['/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_scc1_sor-02-22-25.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_scc1_sor-02-21-23.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_scc1_sor-01-14-19.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_scc1_sor-01-14-18.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_scc1_sor-01-26.czi #8.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_scc1_sor-01-26.czi #6.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_scc1_sor-01-26.czi #5.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_scc1_sor-01-26.czi #1.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_scc1_sor-01-26.czi #4.tif_registered.tif.csv',
#  '/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_whole_axis_length/230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_scc1_sor-01-14-17.tif_registered.tif.csv']

# %%
#csv_files

# %%
#read in length of whole cohesin axis for wapl depleted cells
all_df = []

#read in csv files
for file in csv_files:
    df = pd.read_csv(file, index_col=0, header=0)
    all_df.append(df)
    #change column names
    df.columns = ['image_name', 'area', 'mean', 'stddev', 'intden', 'rawintden', 'length']
    df.rename(columns = {'label':'image_name'}, inplace = True)
    df.rename(columns = {'length':'length_cohesin_axis'}, inplace = True)
    df["condition"] = "length_cohesin_axis"

#concat all dataframes together
frame = pd.concat(all_df, axis=0, ignore_index=True)
#remove duplicated rows
cols = frame.columns

#slice relevant columns into final dataframe
length_cohesin_axis = frame[['image_name','length_cohesin_axis']]

#fully_prometa_chromatin_fragment_length = fully_prometa_chromatin_fragment_length.sort_values('chromatin_segment_length', ascending=False)
#fully_prometa_chromatin_fragment_length_reset = fully_prometa_chromatin_fragment_length.reset_index(drop=True)

results_dir = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/concat_csvs/"

length_cohesin_axis.to_csv(os.path.join(results_dir + "measure_length_cohesin_axis_wapl_dep.csv"), index = False)
#average_length_wapl.to_csv(os.path.join(results_dir + "average_stats_resolved_dna_around_vermicelli_wapl_dep.csv"), index = False)

# %%
#read in length of single cohesin axes

# %%
length_cohesin_axis
# Out:
#                                             image_name  length_cohesin_axis
# 0    230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...                6.698
# 1    230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...                5.677
# 2    230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...                7.155
# 3    230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...               11.212
# 4    230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...                6.872
# ..                                                 ...                  ...
# 130  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...                2.856
# 131  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...               15.268
# 132  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...                8.181
# 133  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...                1.480
# 134  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...                3.528
#
# [135 rows x 2 columns]

# %%
path_single =  "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/line_length_csv_files/wapl_dep/delta_wapl_single_axis_length/"


csv_files = glob.glob(path_single + "*.csv")

### Fetch all files in path

# %%
#csv_files

# %%
all_df = []

#read in csv files
for file in csv_files:
    df = pd.read_csv(file, index_col=0, header=0)
    all_df.append(df)
    #change column names
    df.columns = ['image_name', 'area', 'mean', 'stddev', 'intden', 'rawintden', 'length']
    df.rename(columns = {'length':'length_single_cohesin_axis'}, inplace = True)
    df.rename(columns = {'label':'image_name'}, inplace = True)
    df["condition"] = "single_cohesin_axis_wapl_depleted"

#concat all dataframes together
frame = pd.concat(all_df, axis=0, ignore_index=True)
#remove duplicated rows
cols = frame.columns
#dedup = frame[cols].loc[(frame[cols].shift() != frame[cols]).any(axis=1)]

#slice relevant columns into final dataframe
length_single_axis = frame[['image_name','length_single_cohesin_axis', 'condition']]

#fully_prometa_two_sister_segment = fully_prometa_two_sister_segment.sort_values('edu_segment_length', ascending=False)
#fully_prometa_two_sister_segment_reset = fully_prometa_two_sister_segment.reset_index(drop=True)

results_dir = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/concat_csvs/"

length_single_axis.to_csv(os.path.join(results_dir + "measure_length_single_axis_segments_wapl_dep.csv"), index = False)
#average_length_wapl.to_csv(os.path.join(results_dir + "average_stats_resolved_dna_around_vermicelli_wapl_dep.csv"), index = False)

# %%
sum_cohesin_axis =  length_cohesin_axis.groupby(['image_name'], as_index=False)[['length_cohesin_axis']].sum()
sum_cohesin_axis
# Out:
#                                           image_name  length_cohesin_axis
# 0  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...               73.578
# 1  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...               60.634
# 2  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...               90.843
# 3  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...               73.472
# 4  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...               69.655
# 5  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...               85.311
# 6  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...               87.490
# 7  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...               84.367
# 8  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...               82.418
# 9  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...               96.101

# %%
sum_single_axis =  length_single_axis.groupby(['image_name'], as_index=False)[['length_single_cohesin_axis']].sum()
sum_single_axis
# Out:
#                                           image_name  \
# 0  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 1  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 2  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 3  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 4  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 5  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
# 6  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
# 7  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
# 8  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
# 9  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
#
#    length_single_cohesin_axis
# 0                      69.560
# 1                      58.524
# 2                      78.147
# 3                      68.846
# 4                      64.262
# 5                      76.465
# 6                      84.074
# 7                      79.468
# 8                      77.233
# 9                      94.585

# %%
frames_merged = sum_single_axis.merge(sum_cohesin_axis, on='image_name',  how = "right")
fraction_single_axis = (frames_merged.loc[:, "length_single_cohesin_axis"]) / (frames_merged.loc[:, "length_cohesin_axis"])
percentage_single_axis = ((frames_merged.loc[:, "length_single_cohesin_axis"]) / (frames_merged.loc[:, "length_cohesin_axis"]))*100

frames_merged["fraction_single_axis"] = fraction_single_axis
frames_merged["percentage_single_axis"] = percentage_single_axis

# %%
fraction_split_axes = 1 - (frames_merged.loc[:, "fraction_single_axis"])

# %%
percentage_split_axes = fraction_split_axes *100

# %%
frames_merged["fraction_split_axes"] = fraction_split_axes
frames_merged["percentage_split_axes"] = percentage_split_axes

# %%
frames_merged
# Out:
#                                           image_name  \
# 0  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 1  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 2  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 3  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 4  230304_1802_wapl_dep_ctrl_si_rep1_zoom4_8_dna_...
# 5  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
# 6  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
# 7  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
# 8  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
# 9  230304_1802_wapl_dep_ctrl_si_rep2_zoom4_8_dna_...
#
#    length_single_cohesin_axis  length_cohesin_axis  fraction_single_axis  \
# 0                      69.560               73.578              0.945391
# 1                      58.524               60.634              0.965201
# 2                      78.147               90.843              0.860242
# 3                      68.846               73.472              0.937037
# 4                      64.262               69.655              0.922576
# 5                      76.465               85.311              0.896309
# 6                      84.074               87.490              0.960956
# 7                      79.468               84.367              0.941932
# 8                      77.233               82.418              0.937089
# 9                      94.585               96.101              0.984225
#
#    percentage_single_axis  fraction_split_axes  percentage_split_axes
# 0               94.539129             0.054609               5.460871
# 1               96.520104             0.034799               3.479896
# 2               86.024240             0.139758              13.975760
# 3               93.703724             0.062963               6.296276
# 4               92.257555             0.077424               7.742445
# 5               89.630880             0.103691              10.369120
# 6               96.095554             0.039044               3.904446
# 7               94.193227             0.058068               5.806773
# 8               93.708899             0.062911               6.291101
# 9               98.422493             0.015775               1.577507

# %%
results_dir = "/groups/gerlich/experiments/Experiments_005700/005765/quantify_fraction_split_axes/final_output/"

# %%
frames_merged.to_csv(os.path.join(results_dir + "wapl_depleted_control_percentage_split_axes.csv"), index = False)
#average_length_wapl.to_csv(os.path.join(results_dir + "average_stats_resolved_dna_around_vermicelli_wapl_dep.csv"), index = False)

# %%
sor_fluor = pd.read_csv("/groups/gerlich/experiments/Experiments_005700/005765/quantify_mean_fluorescence_single_cells/1802_wapl_dep_sor_si_16nm_5675.csv")


#slice relevant columns into final dataframe
sor_fluor = sor_fluor[['image_name','mean_sororin']]

# %%
concat_frame = frames_merged = frames_merged.merge(sor_fluor, on='image_name',  how = "right")

# %%
concat_frame = concat_frame.dropna()
concat_frame = concat_frame[['image_name', 'percentage_split_axes', 'mean_sororin']]

# %%
concat_frame.to_csv(os.path.join(results_dir + "wapl_depleted_split_axes_mean_sor_fluorescence.csv"), index = False)
#average_length_wapl.to_csv(os.path.join(results_dir + "average_stats_resolved_dna_around_vermicelli_wapl_dep.csv"), index = False)

# %%
sum_frames = [sum_labelled_edu_fragment, sum_labelled_chromatin_fragment]

# %%
test = pd.concat(sum_frames, axis=1, ignore_index=False)

# %%
test
# Out:
#                                            image_name  \
# 0   211108_5325_WT_12h_release_hemi_60min_STLC_zoo...
# 1   211108_5325_WT_12h_release_hemi_60min_STLC_zoo...
# 2   211108_5325_WT_12h_release_hemi_60min_STLC_zoo...
# 3   211108_5325_WT_12h_release_hemi_60min_STLC_zoo...
# 4   211108_5325_WT_12h_release_hemi_60min_STLC_zoo...
# 5   220207_5389_WT_c1_rep1_prometa_60min_stlc_hemi...
# 6   220207_5389_WT_c1_rep1_prometa_60min_stlc_hemi...
# 7   220207_5389_WT_c1_rep1_prometa_60min_stlc_hemi...
# 8   220207_5389_WT_c1_rep1_prometa_60min_stlc_hemi...
# 9   220207_5389_WT_c1_rep1_prometa_60min_stlc_hemi...
# 10  220207_5389_WT_c1_rep2_prometa_60min_stlc_hemi...
# 11  220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 12  220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 13  220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 14  220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 15  220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 16  220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 17  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 18  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 19  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 20  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 21  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 22  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 23  220405_wt_prometa_rep2_hemi_stain_smc4_cycb1_z...
# 24  220405_wt_prometa_rep2_hemi_stain_smc4_cycb1_z...
# 25  220530_5517_WT_hemi_15h_G2_prometa_rep2_stlc-0...
# 26  220530_5517_WT_hemi_15h_G2_prometa_rep2_stlc-0...
# 27  220530_5517_WT_hemi_15h_G2_prometa_rep2_stlc-0...
# 28  220530_5517_WT_hemi_15h_G2_prometa_rep4_stlc-0...
# 29  220530_5517_WT_hemi_15h_G2_prometa_rep4_stlc-0...
#
#                                     condition  edu_segment_length  \
# 0    hemi_prometa_one_sister_labelled_segment               8.745
# 1    hemi_prometa_one_sister_labelled_segment              38.115
# 2    hemi_prometa_two_sister_labelled_segment               0.387
# 3   hemi_prometa_zero_sister_labelled_segment               0.810
# 4    hemi_prometa_one_sister_labelled_segment              18.196
# 5    hemi_prometa_one_sister_labelled_segment              18.968
# 6    hemi_prometa_one_sister_labelled_segment              20.272
# 7    hemi_prometa_two_sister_labelled_segment               0.565
# 8   hemi_prometa_zero_sister_labelled_segment               1.129
# 9    hemi_prometa_one_sister_labelled_segment              14.387
# 10   hemi_prometa_one_sister_labelled_segment              21.682
# 11   hemi_prometa_one_sister_labelled_segment              14.883
# 12  hemi_prometa_zero_sister_labelled_segment               1.023
# 13   hemi_prometa_one_sister_labelled_segment              14.600
# 14   hemi_prometa_one_sister_labelled_segment              23.903
# 15   hemi_prometa_two_sister_labelled_segment               0.740
# 16  hemi_prometa_zero_sister_labelled_segment               0.564
# 17   hemi_prometa_one_sister_labelled_segment              16.436
# 18   hemi_prometa_one_sister_labelled_segment              28.211
# 19  hemi_prometa_zero_sister_labelled_segment               0.669
# 20   hemi_prometa_one_sister_labelled_segment              16.361
# 21   hemi_prometa_one_sister_labelled_segment              11.424
# 22   hemi_prometa_one_sister_labelled_segment              21.230
# 23   hemi_prometa_one_sister_labelled_segment              22.452
# 24   hemi_prometa_one_sister_labelled_segment              14.349
# 25   hemi_prometa_one_sister_labelled_segment              24.576
# 26  hemi_prometa_zero_sister_labelled_segment               0.318
# 27   hemi_prometa_one_sister_labelled_segment              13.752
# 28   hemi_prometa_one_sister_labelled_segment              21.084
# 29   hemi_prometa_one_sister_labelled_segment              21.089
#
#                                            image_name  \
# 0   211108_5325_WT_12h_release_hemi_60min_STLC_zoo...
# 1   211108_5325_WT_12h_release_hemi_60min_STLC_zoo...
# 2   211108_5325_WT_12h_release_hemi_60min_STLC_zoo...
# 3   220207_5389_WT_c1_rep1_prometa_60min_stlc_hemi...
# 4   220207_5389_WT_c1_rep1_prometa_60min_stlc_hemi...
# 5   220207_5389_WT_c1_rep1_prometa_60min_stlc_hemi...
# 6   220207_5389_WT_c1_rep2_prometa_60min_stlc_hemi...
# 7   220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 8   220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 9   220207_5389_WT_c2_rep1_prometa_60min_stlc_hemi...
# 10  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 11  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 12  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 13  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 14  220207_5389_WT_c2_rep2_prometa_60min_stlc_hemi...
# 15  220405_wt_prometa_rep2_hemi_stain_smc4_cycb1_z...
# 16  220405_wt_prometa_rep2_hemi_stain_smc4_cycb1_z...
# 17  220530_5517_WT_hemi_15h_G2_prometa_rep2_stlc-0...
# 18  220530_5517_WT_hemi_15h_G2_prometa_rep2_stlc-0...
# 19  220530_5517_WT_hemi_15h_G2_prometa_rep4_stlc-0...
# 20  220530_5517_WT_hemi_15h_G2_prometa_rep4_stlc-0...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#     chromatin_segment_length
# 0                      8.745
# 1                     34.237
# 2                     18.196
# 3                     18.968
# 4                     18.825
# 5                     14.387
# 6                     21.682
# 7                     18.832
# 8                     14.600
# 9                     25.595
# 10                    16.436
# 11                    28.418
# 12                    16.361
# 13                    11.424
# 14                    21.230
# 15                    22.452
# 16                    14.349
# 17                    25.139
# 18                    13.752
# 19                    21.084
# 20                    21.089
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
